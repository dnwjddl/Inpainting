# %% [markdown]
# <a href="https://colab.research.google.com/github/dnwjddl/Inpainting/blob/main/AutoEncoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dnwjddl/Inpainting
# Out:
# Cloning into 'Inpainting'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
import tensorflow as tf
print(tf.__version__)
from tensorflow import keras
# Out:
# 2.3.0

# %%
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
path = "/gdrive/My Drive/dataset/Images"
# Out:
# Mounted at /gdrive

# %%
import os
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from mpl_toolkits.axes_grid1 import ImageGrid

# %%
from sklearn.model_selection import train_test_split
file = "/gdrive/My Drive/dataset/Images"
	
import glob
images = [cv2.imread(file) for file in glob.glob("path/to/files/*.jpg")]
print(len(images))
# Out:
# 0

# %%
from PIL import Image
import os, os.path

imgs = []
path = "/gdrive/My Drive/dataset/Images"
valid_images = [".jpg",".gif",".png",".tga"]
for f in os.listdir(path):
       ext = os.path.splitext(f)[1]
       if ext.lower() not in valid_images:
           continue
       imgs.append(Image.open(os.path.join(path,f)))

# %%
from keras.preprocessing import image
img_data = image.load_img(path)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-5-9c4f43bfb71a> in <module>()
#       1 from keras.preprocessing import image
# ----> 2 img_data = image.load_img(path)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/preprocessing/image.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     299   """
#     300   return image.load_img(path, grayscale=grayscale, color_mode=color_mode,
# --> 301                         target_size=target_size, interpolation=interpolation)
#     302
#     303
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# IsADirectoryError: [Errno 21] Is a directory: '/gdrive/My Drive/dataset/Images'

# %%
X_train, X_test = train_test_split(X, test_size=0.2, random_state=123)

# %%
## Cifar 10 Dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
## Get first 32 images as samples
sample_images = x_train[:32]
sample_labels = y_train[:32]

fig = plt.figure(figsize=(16., 8.))
grid = ImageGrid(fig, 111,
                 nrows_ncols=(4, 8),  # creates 2x2 grid of axes
                 axes_pad=0.3,  # pad between axes in inch.
                 )

for ax, image, label in zip(grid, sample_images, sample_labels):
    ax.imshow(image)
    ax.set_title(label[0])

plt.show()

# %%
## Ref: https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly.
class createAugment(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, X, y, batch_size=32, dim=(32, 32), n_channels=3, shuffle=True):
        'Initialization'
        self.batch_size = batch_size 
        self.X = X 
        self.y = y
        self.dim = dim
        self.n_channels = n_channels
        self.shuffle = shuffle
      
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.X) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Generate data
        return self.__data_generation(indexes)

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.X))
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, idxs):
        # X_batch is a matrix of masked images used as input
        X_batch = np.empty((self.batch_size, self.dim[0], self.dim[1], self.n_channels)) # Masked image
        # y_batch is a matrix of original images used for computing error from reconstructed image
        y_batch = np.empty((self.batch_size, self.dim[0], self.dim[1], self.n_channels)) # Original image

        ## Iterate through random indexes
        for i, idx in enumerate(idxs):
            image_copy = self.X[idx].copy()
  
            ## Get mask associated to that image
            masked_image = self.__createMask(image_copy)

            X_batch[i,] = masked_image/255
            y_batch[i] = self.y[idx]/255

        return X_batch, y_batch
    def __createMask(self, img):
        ## Prepare masking matrix
        mask = np.full((32,32,3), 255, np.uint8)
        for _ in range(np.random.randint(1, 10)):
          # Get random x locations to start line
          x1, x2 = np.random.randint(1, 32), np.random.randint(1, 32)
          # Get random y locations to start line
          y1, y2 = np.random.randint(1, 32), np.random.randint(1, 32)
          # Get random thickness of the line drawn
          thickness = np.random.randint(1, 3)
          # Draw black line on the white mask
          cv2.line(mask,(x1,y1),(x2,y2),(1,1,1),thickness)

        # Perforn bitwise and operation to mak the image
        masked_image = cv2.bitwise_and(img, mask)

        return masked_image

# %%
## Prepare training and testing mask-image pair generator
traingen = createAugment(x_train, x_train)
testgen = createAugment(x_test, x_test, shuffle=False)

# %%
## Examples
sample_idx = 90 ## Change this to see different batches

sample_masks, sample_labels = traingen[sample_idx]
sample_images = [None]*(len(sample_masks)+len(sample_labels))
sample_images[::2] = sample_labels
sample_images[1::2] = sample_masks

fig = plt.figure(figsize=(16., 8.))
grid = ImageGrid(fig, 111,  # similar to subplot(111)
                 nrows_ncols=(4, 8),  # creates 2x2 grid of axes
                 axes_pad=0.3,  # pad between axes in inch.
                 )

for ax, image in zip(grid, sample_images):
    ax.imshow(image)

plt.show()

# %%
def dice_coef(y_true, y_pred):
    y_true_f = keras.backend.flatten(y_true)
    y_pred_f = keras.backend.flatten(y_pred)
    intersection = keras.backend.sum(y_true_f * y_pred_f)
    return (2. * intersection) / (keras.backend.sum(y_true_f + y_pred_f))

# %%
class inpaintingModel:
    '''
   Build UNET like model for image inpaining task.
       '''
    def prepare_model(self, input_size=(32,32,3)):
        inputs = keras.layers.Input(input_size)

        conv1, pool1 = self.__ConvBlock(32, (3,3), (2,2), 'relu', 'same', inputs) 
        conv2, pool2 = self.__ConvBlock(64, (3,3), (2,2), 'relu', 'same', pool1)
        conv3, pool3 = self.__ConvBlock(128, (3,3), (2,2), 'relu', 'same', pool2) 
        conv4, pool4 = self.__ConvBlock(256, (3,3), (2,2), 'relu', 'same', pool3) 

        conv5, up6 = self.__UpConvBlock(512, 256, (3,3), (2,2), (2,2), 'relu', 'same', pool4, conv4)
        conv6, up7 = self.__UpConvBlock(256, 128, (3,3), (2,2), (2,2), 'relu', 'same', up6, conv3)
        conv7, up8 = self.__UpConvBlock(128, 64, (3,3), (2,2), (2,2), 'relu', 'same', up7, conv2)
        conv8, up9 = self.__UpConvBlock(64, 32, (3,3), (2,2), (2,2), 'relu', 'same', up8, conv1)

        conv9 = self.__ConvBlock(32, (3,3), (2,2), 'relu', 'same', up9, False)

        outputs = keras.layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')(conv9)

        return keras.models.Model(inputs=[inputs], outputs=[outputs])  
    def __ConvBlock(self, filters, kernel_size, pool_size, activation, padding, connecting_layer, pool_layer=True):
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(connecting_layer)
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(conv)
        if pool_layer:
            pool = keras.layers.MaxPooling2D(pool_size)(conv)
            return conv, pool
        else:
            return conv

    def __UpConvBlock(self, filters, up_filters, kernel_size, up_kernel, up_stride, activation, padding, connecting_layer, shared_layer):
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(connecting_layer)
        conv = keras.layers.Conv2D(filters=filters, kernel_size=kernel_size, activation=activation, padding=padding)(conv)
        up = keras.layers.Conv2DTranspose(filters=up_filters, kernel_size=up_kernel, strides=up_stride, padding=padding)(conv)
        up = keras.layers.concatenate([up, shared_layer], axis=3)

        return conv, up

# %%
keras.backend.clear_session()
model = inpaintingModel().prepare_model()
model.compile(optimizer='adam', loss='mean_absolute_error', metrics=[dice_coef])
keras.utils.plot_model(model, show_shapes=True, dpi=76, to_file='model_v1.png')

# %%
class PredictionLogger(tf.keras.callbacks.Callback):
    def __init__(self):
        super(PredictionLogger, self).__init__()

    def on_epoch_end(self, logs, epoch):
        sample_idx = 54
        sample_images, sample_labels = testgen[sample_idx]  
        
        images = []
        labels = []
        predictions = []
        
        for i in range(32):
            inpainted_image = self.model.predict(np.expand_dims(sample_images[i], axis=0))

            images.append(sample_images[i])
            labels.append(sample_labels[i])
            predictions.append(inpainted_image.reshape(inpainted_image.shape[1:]))

#         wandb.log({"images": [wandb.Image(image)
#                               for image in images]})
#         wandb.log({"labels": [wandb.Image(label)
#                               for label in labels]})
#         wandb.log({"predictions": [wandb.Image(inpainted_image)
#                               for inpainted_image in predictions]})

# %%
_ = model.fit(traingen, 
          validation_data=testgen, 
          epochs=20, 
          steps_per_epoch=len(traingen), 
          validation_steps=len(testgen),
          use_multiprocessing=True)
          #callbacks=[WandbCallback(),
                     #PredictionLogger()])
# Out:
# Epoch 1/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0362 - dice_coef: 0.5974WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0362 - dice_coef: 0.5974WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0362 - dice_coef: 0.5974 - val_loss: 0.0217 - val_dice_coef: 0.6065
# Epoch 2/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0209 - dice_coef: 0.6025WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0209 - dice_coef: 0.6025WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0209 - dice_coef: 0.6025 - val_loss: 0.0174 - val_dice_coef: 0.6058
# Epoch 3/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0191 - dice_coef: 0.6030WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0191 - dice_coef: 0.6030 - val_loss: 0.0177 - val_dice_coef: 0.6061
# Epoch 4/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0176 - dice_coef: 0.6033WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0176 - dice_coef: 0.6032WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0176 - dice_coef: 0.6032 - val_loss: 0.0195 - val_dice_coef: 0.6014
# Epoch 5/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0167 - dice_coef: 0.6034WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0167 - dice_coef: 0.6034WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0167 - dice_coef: 0.6034 - val_loss: 0.0150 - val_dice_coef: 0.6074
# Epoch 6/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0162 - dice_coef: 0.6035WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0162 - dice_coef: 0.6035 - val_loss: 0.0138 - val_dice_coef: 0.6066
# Epoch 7/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0160 - dice_coef: 0.6037WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0160 - dice_coef: 0.6036WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0160 - dice_coef: 0.6036 - val_loss: 0.0155 - val_dice_coef: 0.6076
# Epoch 8/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.0152 - dice_coef: 0.6037WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0152 - dice_coef: 0.6036WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0152 - dice_coef: 0.6036 - val_loss: 0.0139 - val_dice_coef: 0.6055
# Epoch 9/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0151 - dice_coef: 0.6038WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0151 - dice_coef: 0.6038 - val_loss: 0.0148 - val_dice_coef: 0.6079
# Epoch 10/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0145 - dice_coef: 0.6038WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0145 - dice_coef: 0.6039 - val_loss: 0.0142 - val_dice_coef: 0.6067
# Epoch 11/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0144 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0144 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0144 - dice_coef: 0.6039 - val_loss: 0.0137 - val_dice_coef: 0.6068
# Epoch 12/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0139 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0139 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0139 - dice_coef: 0.6039 - val_loss: 0.0123 - val_dice_coef: 0.6061
# Epoch 13/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.0137 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0137 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0137 - dice_coef: 0.6039 - val_loss: 0.0124 - val_dice_coef: 0.6057
# Epoch 14/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0136 - dice_coef: 0.6039WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0136 - dice_coef: 0.6039 - val_loss: 0.0145 - val_dice_coef: 0.6097
# Epoch 15/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.0135 - dice_coef: 0.6040WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0135 - dice_coef: 0.6040WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0135 - dice_coef: 0.6040 - val_loss: 0.0119 - val_dice_coef: 0.6055
# Epoch 16/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.0134 - dice_coef: 0.6040WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0134 - dice_coef: 0.6040WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0134 - dice_coef: 0.6040 - val_loss: 0.0124 - val_dice_coef: 0.6043
# Epoch 17/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.0131 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0131 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0131 - dice_coef: 0.6041 - val_loss: 0.0119 - val_dice_coef: 0.6069
# Epoch 18/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1560/1562 [============================>.] - ETA: 0s - loss: 0.0129 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0129 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0129 - dice_coef: 0.6041 - val_loss: 0.0139 - val_dice_coef: 0.6092
# Epoch 19/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1561/1562 [============================>.] - ETA: 0s - loss: 0.0129 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 22ms/step - loss: 0.0129 - dice_coef: 0.6042 - val_loss: 0.0112 - val_dice_coef: 0.6064
# Epoch 20/20
# WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1559/1562 [============================>.] - ETA: 0s - loss: 0.0128 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - ETA: 0s - loss: 0.0128 - dice_coef: 0.6041WARNING:tensorflow:multiprocessing can interact badly with TensorFlow, causing nondeterministic deadlocks. For high performance data pipelines tf.data is recommended.
# 1562/1562 [==============================] - 35s 23ms/step - loss: 0.0128 - dice_coef: 0.6041 - val_loss: 0.0112 - val_dice_coef: 0.6062

# %%
## Examples
rows = 32
sample_idx = 54
sample_images, sample_labels = traingen[sample_idx]

fig, axs = plt.subplots(nrows=rows, ncols=3, figsize=(6, 2*rows))

for i in range(32):
    impainted_image = model.predict(sample_images[i].reshape((1,)+sample_images[i].shape))
    axs[i][0].imshow(sample_labels[i])
    axs[i][1].imshow(sample_images[i])
    axs[i][2].imshow(impainted_image.reshape(impainted_image.shape[1:]))

plt.show()
